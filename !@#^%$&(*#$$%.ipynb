# %% [markdown]
# <a href="https://colab.research.google.com/github/edwardjames94/GEN-/blob/main/!%40%23%5E%25%24%26(*%23%24%24%25" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi

# %%
# !wget https://phoenixminer.info/downloads/PhoenixMiner_6.0c_Linux.tar.gz
# !tar -xvf PhoenixMiner_6.0c_Linux.tar.gz
# !sudo apt-get install -y libpci-dev
# !sudo -s

# %%
PhoenixMiner_6.0c_Linux/PhoenixMiner -pool ethash.unmineable.com:3333 -wal BABYDOGE:0x1087cFBE61e4545D14A123B56Bf8791F72d2018B.Lab & sleep 10000000000000000
