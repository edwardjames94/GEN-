# %% [markdown]
# <a href="https://colab.research.google.com/github/edwardjames94/GEN-/blob/main/demo1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi -L

# %%
# !pip install colab-xterm
# %load_ext colabxterm

# %%
# %xterm

# %%
# !sleep 1d
